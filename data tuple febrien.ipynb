# %%
my_tuple = (1, "Hello", 3.14, True)

#tuple dengan berbagai tipe data#

# %%
nested_tuple = ((1, 2, 3), (4, 5, 6), (7, 8, 9))

#Tuple nested (tuple dalam tuple)#

# %%
point = (2, 3)

#Tuple sebagai koordinat#

# %%
days_of_week = ("Senin", "Selasa", "Rabu", "Kamis", "Jumat", "Sabtu", "Minggu")

#Tuple dalam pengulangan#

# %%
person = {
    ("anil", "ari"): 30,
    ("fuad", "ilham"): 25}

#Tuple sebagai nilai kunci dalam kamus (dictionary)#

# %% [markdown]
# Tipe data tuple adalah tipe data yang tidak dapat diubah (immutable) setelah dibuat. Anda dapat mengakses elemen-elemen dalam tuple menggunakan indeks, seperti my_tuple[0] untuk mengakses elemen pertama.
