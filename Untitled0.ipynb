# %%
list_kosong = []

# %%
list_buah = ["pisang", "nanas", "melon", "durian"]

# %%
list_angka = [100,200,400,800,1600]

# %%
list_campur = ["nasi", 200,1000,5000, "ikan", True, False]

# %%
print ('list kosong', list_kosong)
# Out:
# list kosong []

# %%
print ('isi list buah', list_buah)
# Out:
# isi list buah ['pisang', 'nanas', 'melon', 'durian']

# %%
print ('isi list campur', list_campur)
# Out:
# isi list campur ['nasi', 200, 1000, 5000, 'ikan', True, False]

# %%
print(list_buah[0])
print(list_buah[1])
print(list_buah[2])
print(list_buah[3])
# Out:
# pisang
# nanas
# melon
# durian

# %%
print(list_buah[0:1])
# Out:
# ['pisang']

# %%
print(list_buah[0:2])
# Out:
# ['pisang', 'nanas']

# %%
print(list_buah[1:3])
# Out:
# ['nanas', 'melon']

# %%
print(list_buah[0:])
# Out:
# ['pisang', 'nanas', 'melon', 'durian']

# %%
print(list_buah[1:])
# Out:
# ['nanas', 'melon', 'durian']

# %%
print(list_buah)
# Out:
# ['pisang', 'nanas', 'melon', 'durian']

# %%
list_buah[0] ="jeruk"

# %%
list_buah[-1] ="mangga"

# %%
print(list_buah)
# Out:
# ['jeruk', 'nanas', 'melon', 'mangga']

# %%
list_buah[1:3] = ["buah naga", "pepaya"]

# %%
print(list_buah)
# Out:
# ['jeruk', 'buah naga', 'pepaya', 'mangga']

# %%
list_buah.append("sirsak")

# %%
print(list_buah)
# Out:
# ['jeruk', 'buah naga', 'pepaya', 'mangga', 'sirsak']

# %%
list_buah.insert(0, "jambu")

# %%
print(list_buah)
# Out:
# ['jambu', 'pepaya', 'manggis', 'mangga', 'sirsak']

# %%
list_buah.insert(2, "manggis")

# %%
print(list_buah)
# Out:
# ['jambu', 'jeruk', 'manggis', 'buah naga', 'pepaya', 'mangga', 'sirsak']

# %%
del list_buah[1]

# %%
print(list_buah)
# Out:
# ['pepaya', 'mangga', 'sirsak']

# %%
angka_yang_terhapus = list_angka.pop()

# %%
print ("angka_yang terhapus", angka_yang_terhapus)
# Out:
# angka_yang terhapus 1600

# %%
a = [1, 2, 3]
b = ["a"]
c = [True, "b", False]

# %%
list_angka.sort()
print(list_angka)

[1, 4, 5, 1000, 3000]
# Out:
# [100, 200, 400, 800]
# [1, 4, 5, 1000, 3000]

# %%
list_angka.reverse
